# %% [markdown]
# ## **Data Visualization using Seaborn**

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### ***why seaborn?***

# %% [markdown]
# ### **Seaborn vs. Matplotlib: Key Points**
#
# **1. Ease of Use**
#    - **Seaborn**: Higher-level interface, simpler commands for complex visualizations.
#    - **Matplotlib**: Lower-level control, requires more lines of code.
#
# **2. Aesthetic Appeal**
#    - **Seaborn**: Beautiful default styles and color palettes.
#    - **Matplotlib**: Highly customizable but less attractive by default.
#
# **3. Statistical Plots**
#    - **Seaborn**: Built-in support for statistical plots (e.g., regression, heatmaps).
#    - **Matplotlib**: Requires additional coding for similar plots.
#
# **4. Integrations**
#    - **Seaborn**: Better integration with Pandas data frames.
#    - **Matplotlib**: Integrates well but needs more manual effort.
#
# **5. Complexity**
#    - **Seaborn**: Ideal for quick, high-level analysis.
#    - **Matplotlib**: Better for detailed, customized visualizations.

# %% [markdown]
# ### ***Types of function in seaborn***

# %% [markdown]
# - **Figure Level** : Works with the entire figure and can create complex visualizations using multiple subplots
# - **Axes Level** : Operates on a single set of axes, typically creating a single plot

# %% [markdown]
# ### ***Main classification of Graphs*** ###

# %% [markdown]
# - **Relational Plot**
# - **Distribution Plot**
# - **Categorical Plot**
# - **Regression Plot**
# - **Matrix Plot**
# - **Multiplots**

# %% [markdown]
# ### ***1.Relational Plot***

# %% [markdown]
# - to see the statistical relation between 2 or more variables
# - Bivariate analysis

# %% [markdown]
# plots under this:
# - ***Scatterplot***
# - ***lineplot***

# %% [markdown]
# ### ***Scatterplot()***

# %%
#scatterplot
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#scatterplot ---> usign axes function
sns.scatterplot(data=tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#scatter plot using figure level function
sns.relplot(data=tips,x='total_bill',y='tip',kind = 'scatter')

# %%
#customization
sns.relplot(data=tips,x='total_bill',y='tip',kind = 'scatter',hue='sex',style='smoker',size = 'size')

# %% [markdown]
# ### ***lineplot()***

# %%
gap = px.data.gapminder()
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
temp_df = gap[gap['country']=='Nepal']
temp_df
# Out:
#      country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 1068   Nepal      Asia  1952   36.157   9182536   545.865723       NPL
# 1069   Nepal      Asia  1957   37.686   9682338   597.936356       NPL
# 1070   Nepal      Asia  1962   39.393  10332057   652.396859       NPL
# 1071   Nepal      Asia  1967   41.472  11261690   676.442225       NPL
# 1072   Nepal      Asia  1972   43.971  12412593   674.788130       NPL
# 1073   Nepal      Asia  1977   46.748  13933198   694.112440       NPL
# 1074   Nepal      Asia  1982   49.594  15796314   718.373095       NPL
# 1075   Nepal      Asia  1987   52.537  17917180   775.632450       NPL
# 1076   Nepal      Asia  1992   55.727  20326209   897.740360       NPL
# 1077   Nepal      Asia  1997   59.426  23001113  1010.892138       NPL
# 1078   Nepal      Asia  2002   61.340  25873917  1057.206311       NPL
# 1079   Nepal      Asia  2007   63.785  28901790  1091.359778       NPL
#
#       iso_num
# 1068      524
# 1069      524
# 1070      524
# 1071      524
# 1072      524
# 1073      524
# 1074      524
# 1075      524
# 1076      524
# 1077      524
# 1078      524
# 1079      524

# %%
# using axes level function
sns.lineplot(data=temp_df,x='year',y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# using relplot
sns.relplot(data=temp_df,x='year',y='lifeExp',kind='line')

# %%
# lets extract data of nepal,india and china
temp_df = gap[gap['country'].isin(['Nepal','China','India'])]
temp_df
# Out:
#      country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 288    China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289    China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290    China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291    China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292    China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293    China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294    China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295    China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296    China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297    China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298    China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# 299    China      Asia  2007  72.96100  1318683096  4959.114854       CHN
# 696    India      Asia  1952  37.37300   372000000   546.565749       IND
# 697    India      Asia  1957  40.24900   409000000   590.061996       IND
# 698    India      Asia  1962  43.60500   454000000   658.347151       IND
# 699    India      Asia  1967  47.19300   506000000   700.770611       IND
# 700    India      Asia  1972  50.65100   567000000   724.032527       IND
# 701    India      Asia  1977  54.20800   634000000   813.337323       IND
# 702    India      Asia  1982  56.59600   708000000   855.723538       IND
# 703    India      Asia  1987  58.55300   788000000   976.512676       IND
# 704    India      Asia  1992  60.22300   872000000  1164.406809       IND
# 705    India      Asia  1997  61.76500   959000000  1458.817442       IND
# 706    India      Asia  2002  62.87900  1034172547  1746.769454       IND
# 707    India      Asia  2007  64.69800  1110396331  2452.210407       IND
# 1068   Nepal      Asia  1952  36.15700     9182536   545.865723       NPL
# 1069   Nepal      Asia  1957  37.68600     9682338   597.936356       NPL
# 1070   Nepal      Asia  1962  39.39300    10332057   652.396859       NPL
# 1071   Nepal      Asia  1967  41.47200    11261690   676.442225       NPL
# 1072   Nepal      Asia  1972  43.97100    12412593   674.788130       NPL
# 1073   Nepal      Asia  1977  46.74800    13933198   694.112440       NPL
# 1074   Nepal      Asia  1982  49.59400    15796314   718.373095       NPL
# 1075   Nepal      Asia  1987  52.53700    17917180   775.632450       NPL
# 1076   Nepal      Asia  1992  55.72700    20326209   897.740360       NPL
# 1077   Nepal      Asia  1997  59.42600    23001113  1010.892138       NPL
# 1078   Nepal      Asia  2002  61.34000    25873917  1057.206311       NPL
# 1079   Nepal      Asia  2007  63.78500    28901790  1091.359778       NPL
#
#       iso_num
# 288       156
# 289       156
# 290       156
# 291       156
# 292       156
# 293       156
# 294       156
# 295       156
# 296       156
# 297       156
# 298       156
# 299       156
# 696       356
# 697       356
# 698       356
# 699       356
# 700       356
# 701       356
# 702       356
# 703       356
# 704       356
# 705       356
# 706       356
# 707       356
# 1068      524
# 1069      524
# 1070      524
# 1071      524
# 1072      524
# 1073      524
# 1074      524
# 1075      524
# 1076      524
# 1077      524
# 1078      524
# 1079      524

# %%
sns.relplot(kind='line', data = temp_df, x='year',y='lifeExp',hue = 'country')

# %%
#facet plot
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data = tips,x='total_bill',y='tip',kind = 'scatter',col='sex') #side by side graph based on sex

# %%
sns.relplot(data = tips,x='total_bill',y='tip',kind = 'scatter',row = 'day', col='sex',hue='sex',style = 'smoker')

# %%
sns.relplot(data = tips,x='total_bill',y='tip',kind = 'scatter',row = 'time', col='sex',hue='sex',style = 'smoker')

# %% [markdown]
# ***note: facet plot only work with figure level function (relplot)***

# %%
#col wrap
sns.relplot(data = gap,x = 'lifeExp',y='gdpPercap',col='year',col_wrap=3,hue='continent')

# %%
sns.relplot(data = gap,x = 'lifeExp',y='gdpPercap',col='continent',col_wrap=3,hue='year')

# %% [markdown]
# ### ***2. Distribution Plot***

# %% [markdown]
# - *used for univariate analysis*
# - *used to find out the observayion*
# - *Range of the observation*
# - *Central tendency*
# - *is the data bimodel*
# - *Are there outliers*

# %% [markdown]
# ### **plots under distribution plot**
# - ***histplot***
# - ***kdeplot***
# - ***rugplot***

# %% [markdown]
# - ***figure level function*** : displot()
# - ***axes level function*** : histplot(), kdeplot(), rugplot()

# %% [markdown]
# ### ***histplot()***

# %%
#plotting univariate histogram
sns.displot(data = tips['total_bill'],kind = 'hist') #bins can be defined using bins=

# %%
#histogram on categorical column
sns.displot(data = tips['day'],kind = 'hist')

# %%
sns.displot(data = tips,x = 'tip',kind = 'hist',hue = 'sex')

# %%
#element --> step
sns.displot(data = tips,x = 'tip', kind = 'hist',hue='sex',element = 'step')

# %%
#faceting using col and row
sns.displot(data = tips,x = 'tip', kind = 'hist',col='sex')

# %% [markdown]
# ### ***kdeplot()***

# %%
#not using dicrete bins like histogram
sns.displot(kind = 'kde',data = tips,x = 'total_bill')

# %%
sns.displot(kind = 'kde',data = tips,x = 'total_bill',hue='sex')

# %% [markdown]
# I can understand data distribution more clearly for both male and female in kdeplot than in histogram using hue = 'sex'

# %%
sns.displot(kind = 'kde',data = tips,x = 'total_bill',hue='sex',fill = True)

# %% [markdown]
# ### ***Rugplot()***

# %% [markdown]
# - *plot marginal distribution by drawing ticks along the x and y axes*
# - *this function is intended to complement other functions*

# %%
sns.kdeplot(data = tips,x = 'total_bill')
sns.rugplot(data = tips,x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### ***Bivariate histogram***

# %%
sns.histplot(data = tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# *here we are visualizing a distribution (frequency of total_bill over tip),the darker area represent there is high total_bill and tip and lighter area represent frequency count is low*

# %% [markdown]
# ### ***Bivariate kdeplot***

# %%
sns.kdeplot(data = tips,x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### **3. Matrix plot**
# - *Heatmap*
# - *clustermap*

# %% [markdown]
# ***Heatmap***

# %%
# plot a rectangular data as color-encoded matrix
temp_data = gap.pivot(index = 'country',columns = 'year',values = 'lifeExp')
temp_data
# Out:
# year                  1952    1957    1962    1967    1972    1977    1982  \
# country
# Afghanistan         28.801  30.332  31.997  34.020  36.088  38.438  39.854
# Albania             55.230  59.280  64.820  66.220  67.690  68.930  70.420
# Algeria             43.077  45.685  48.303  51.407  54.518  58.014  61.368
# Angola              30.015  31.999  34.000  35.985  37.928  39.483  39.942
# Argentina           62.485  64.399  65.142  65.634  67.065  68.481  69.942
# ...                    ...     ...     ...     ...     ...     ...     ...
# Vietnam             40.412  42.887  45.363  47.838  50.254  55.764  58.816
# West Bank and Gaza  43.160  45.671  48.127  51.631  56.532  60.765  64.406
# Yemen, Rep.         32.548  33.970  35.180  36.984  39.848  44.175  49.113
# Zambia              42.038  44.077  46.023  47.768  50.107  51.386  51.821
# Zimbabwe            48.451  50.469  52.358  53.995  55.635  57.674  60.363
#
# year                  1987    1992    1997    2002    2007
# country
# Afghanistan         40.822  41.674  41.763  42.129  43.828
# Albania             72.000  71.581  72.950  75.651  76.423
# Algeria             65.799  67.744  69.152  70.994  72.301
# Angola              39.906  40.647  40.963  41.003  42.731
# Argentina           70.774  71.868  73.275  74.340  75.320
# ...                    ...     ...     ...     ...     ...
# Vietnam             62.820  67.662  70.672  73.017  74.249
# West Bank and Gaza  67.046  69.718  71.096  72.370  73.422
# Yemen, Rep.         52.922  55.599  58.020  60.308  62.698
# Zambia              50.821  46.100  40.238  39.193  42.384
# Zimbabwe            62.351  60.377  46.809  39.989  43.487
#
# [142 rows x 12 columns]

# %%
#heatmap is axes level function , no any figure level function
plt.figure(figsize=(15,10))
sns.heatmap(temp_data)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# lets try with asian countries
gap_asia = gap[gap['continent'] == 'Asia'].pivot(index='country',columns = 'year',values = 'lifeExp')
gap_asia
# Out:
# year                  1952      1957      1962      1967      1972      1977  \
# country
# Afghanistan         28.801  30.33200  31.99700  34.02000  36.08800  38.43800
# Bahrain             50.939  53.83200  56.92300  59.92300  63.30000  65.59300
# Bangladesh          37.484  39.34800  41.21600  43.45300  45.25200  46.92300
# Cambodia            39.417  41.36600  43.41500  45.41500  40.31700  31.22000
# China               44.000  50.54896  44.50136  58.38112  63.11888  63.96736
# Hong Kong, China    60.960  64.75000  67.65000  70.00000  72.00000  73.60000
# India               37.373  40.24900  43.60500  47.19300  50.65100  54.20800
# Indonesia           37.468  39.91800  42.51800  45.96400  49.20300  52.70200
# Iran                44.869  47.18100  49.32500  52.46900  55.23400  57.70200
# Iraq                45.320  48.43700  51.45700  54.45900  56.95000  60.41300
# Israel              65.390  67.84000  69.39000  70.75000  71.63000  73.06000
# Japan               63.030  65.50000  68.73000  71.43000  73.42000  75.38000
# Jordan              43.158  45.66900  48.12600  51.62900  56.52800  61.13400
# Korea, Dem. Rep.    50.056  54.08100  56.65600  59.94200  63.98300  67.15900
# Korea, Rep.         47.453  52.68100  55.29200  57.71600  62.61200  64.76600
# Kuwait              55.565  58.03300  60.47000  64.62400  67.71200  69.34300
# Lebanon             55.928  59.48900  62.09400  63.87000  65.42100  66.09900
# Spain                   64.940  66.660  69.690  71.440  73.060  74.390
# Sweden                  71.860  72.490  73.370  74.160  74.720  75.440
# Switzerland             69.620  70.560  71.320  72.770  73.780  75.390
# Turkey                  43.585  48.079  52.098  54.336  57.005  59.507
# United Kingdom          69.180  70.420  70.760  71.360  72.010  72.760
#
# year                      1982    1987    1992    1997    2002    2007
# country
# Albania                 70.420  72.000  71.581  72.950  75.651  76.423
# Austria                 73.180  74.940  76.040  77.510  78.980  79.829
# Belgium                 73.930  75.350  76.460  77.530  78.320  79.441
# Bosnia and Herzegovina  70.690  71.140  72.178  73.244  74.090  74.852
# Bulgaria                71.080  71.340  71.190  70.320  72.140  73.005
# Croatia                 70.460  71.520  72.527  73.680  74.876  75.748
# Czech Republic          70.960  71.580  72.400  74.010  75.510  76.486
# Denmark                 74.630  74.800  75.330  76.110  77.180  78.332
# Finland                 74.550  74.830  75.700  77.130  78.370  79.313
# France                  74.890  76.340  77.460  78.640  79.590  80.657
# Germany                 73.800  74.847  76.070  77.340  78.670  79.406
# Greece                  75.240  76.670  77.030  77.869  78.256  79.483
# Hungary                 69.390  69.580  69.170  71.040  72.590  73.338
# Iceland                 76.990  77.230  78.770  78.950  80.500  81.757
# Ireland                 73.100  74.360  75.467  76.122  77.783  78.885
# Italy                   74.980  76.420  77.440  78.820  80.240  80.546
# Montenegro              74.101  74.865  75.435  75.445  73.981  74.543
# Netherlands             76.050  76.830  77.420  78.030  78.530  79.762
# Norway                  75.970  75.890  77.320  78.320  79.050  80.196
# Poland                  71.320  70.980  70.990  72.750  74.670  75.563
# Portugal                72.770  74.060  74.860  75.970  77.290  78.098
# Romania                 69.660  69.530  69.360  69.720  71.322  72.476
# Serbia                  70.162  71.218  71.659  72.232  73.213  74.002
# Slovak Republic         70.800  71.080  71.380  72.710  73.800  74.663
# Slovenia                71.063  72.250  73.640  75.130  76.660  77.926
# Spain                   76.300  76.900  77.570  78.770  79.780  80.941
# Sweden                  76.420  77.190  78.160  79.390  80.040  80.884
# Switzerland             76.210  77.410  78.030  79.370  80.620  81.701
# Turkey                  61.036  63.108  66.146  68.835  70.845  71.777
# United Kingdom          74.040  75.007  76.420  77.218  78.471  79.425

# %%
plt.figure(figsize = (15,15))
sns.heatmap(gap_europe,annot=True,linewidths=0.5,cmap = 'winter') #create box makig more readable and clar graph (linewidth),color change using cmap
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
gap.loc[gap['lifeExp'].idxmax()]
# Out:
# country            Japan
# continent           Asia
# year                2007
# lifeExp           82.603
# pop            127467972
# gdpPercap    31656.06806
# iso_alpha            JPN
# iso_num              392
# Name: 803, dtype: object

# %% [markdown]
# *using seaborn heatmap we can visually see the life expectancy of continets europe has better then asia and africa has worse. High life Exectancy is in japan*

# %% [markdown]
# ***clustermap***

# %% [markdown]
# *clustermap is used to check similarity between the data attributes columns or data itself*

# %%
#lets load iris dataset
iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])

# %% [markdown]
# internally here hierarchical agglomerative clustering is working
